# %% [markdown]
# # Step 3
#
# #### Dont forget to tunnel....

# %%
#Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pymongo
from pymongo import MongoClient

# %%
#Entering UBC MongoDB System

CWL = 'ehdz1305'
SNUM = '22168454'

if CWL.strip() == "" or CWL == 'Put your CWL here' or SNUM.strip() == "" or SNUM == 'Put your SNUM here':
    print("You need up to update the value of the CWL and/or SNUM variables before proceeding.")
elif SNUM[0] == "a":
    print("You don't need to include the a here. Just include your student number as a string such as \"12345678\".")
else:
    connection_string = f"mongodb://{CWL}:a{SNUM}@localhost:27017/{CWL}"
    client = pymongo.MongoClient(connection_string)
    db = client[CWL]["project"]

# %%
cur = db['Movie'].find({'startYear' : {"$gt":2021}}, {"startYear":1, "_id":0})

for c in cur:
    print(c)
# Out:
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2023.0}
# {'startYear': 2023.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}
# {'startYear': 2022.0}

# %%
test_data = pd.DataFrame(list(db['Movie'].find({'startYear' : {"$gte":2021}}, {"startYear":1, "_id":0})))


test_data
# Out:
#       startYear
# 0        2021.0
# 1        2023.0
# 2        2022.0
# 3        2021.0
# 4        2022.0
# ...         ...
# 1135     2021.0
# 1136     2022.0
# 1137     2022.0
# 1138     2022.0
# 1139     2021.0
#
# [1140 rows x 1 columns]

# %%
plt.plot(test_data['startYear'].to_list())

# %%
plt.pie(test_data.value_counts().to_list(), labels = ['2022','2021', '2023'])
plt.show()

# %%
test_data.value_counts()
# Out:
# startYear
# 2022.0       618
# 2021.0       320
# 2023.0       202
# Name: count, dtype: int64
